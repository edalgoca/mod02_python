# %%
import pandas as pd

# %%
df_asistencia=pd.read_csv("https://raw.githubusercontent.com/edalgoca/mod02_python/main/20220610.csv")
df_asistencia
# Out:
#            fecha   codigo                                      facultad  \
# 0     2022-02-16   PSEX-H                 Facultad de Ciencias Sociales
# 1     2022-02-16  INGC5-I                 Facultad de Ciencias Sociales
# 2     2022-02-16   PPT1-H                 Facultad de Ciencias Sociales
# 3     2022-02-16   REA1-A                 Facultad de Ciencias Sociales
# 4     2022-02-16   OCOM-I  Facultad de Informática y Ciencias Aplicadas
# ...          ...      ...                                           ...
# 4790  2022-06-10   ETS4-T  Facultad de Informática y Ciencias Aplicadas
# 4791  2022-06-10   INI8-I                 Facultad de Ciencias Sociales
# 4792  2022-06-10  DIIN-DG  Facultad de Informática y Ciencias Aplicadas
# 4793  2022-06-10   PSEM-H                 Facultad de Ciencias Sociales
# 4794  2022-06-10   AUFI-E            Facultad de Ciencias Empresariales
#
#                                       area                           materia  \
# ...

# %%
type(df_asistencia)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df_asistencia.shape)
# Out:
# (4795, 13)

# %%
print(df_asistencia.size)
# Out:
# 62335

# %%
print(df_asistencia.sample(3))
# Out:
#            fecha  codigo                                      facultad  \
# 3447  2022-05-17  ADCC-I  Facultad de Informática y Ciencias Aplicadas
# 3656  2022-05-18   IA1-H                 Facultad de Ciencias Sociales
# 2445  2022-04-20  BIOG-H                 Facultad de Ciencias Sociales
#
#              area                       materia  seccion      horario  \
# 3447  INFORMATICA  ADMÓN. DE CENTROS DE CÓMPUTO        2  18:40-20:10
# 3656      IDIOMAS             INGLÉS AVANZADO I        2  09:45-11:15
# 2445   PSICOLOGIA              BIOLOGÍA GENERAL        2  18:40-20:10
#
#             dias evaluacion       tipo  inscritos  examinados   modalidad
# 3447      Ma-Jue     CUARTA  ORDINARIA         82          77    EN LINEA
# 3656  Lu-Mie-Vie     CUARTA  ORDINARIA         15          14  PRESENCIAL
# 2445      Lu-Mie    TERCERA  ORDINARIA         93          80    EN LINEA

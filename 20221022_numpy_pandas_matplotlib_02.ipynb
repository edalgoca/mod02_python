# %%
# Importamos pandas como pd
import pandas as pd
# creamos nuestro dataframe al cargar un archivo .csv (valores separados por comas)
df = pd.read_json('https://tecnologica.utec.edu.sv/fica/services/examinados.php')

# %%
# mostramos los primeros valores del dataframe
df.head()
# Out:
#         fecha   codigo                       facultad            area  \
# 0  2022-08-22   DEIN-H  Facultad de Ciencias Sociales      PSICOLOGIA
# 1  2022-08-22  EPRO-AC  Facultad de Ciencias Sociales    ANTROPOLOGIA
# 2  2022-08-22   ING1-H  Facultad de Ciencias Sociales         IDIOMAS
# 3  2022-08-22   BIOG-H  Facultad de Ciencias Sociales      PSICOLOGIA
# 4  2022-08-22   FOPU-H  Facultad de Ciencias Sociales  COMUNICACIONES
#
#                    materia  seccion      horario    dias evaluacion  \
# 0    DESARROLLO INDIVIDUAL        3  08:00-09:30  Lu-Vie    PRIMERA
# 1                    ÉTICA        2  08:00-09:30  Lu-Vie    PRIMERA
# 2                 INGLÉS I        4  08:00-09:30  Lu-Vie    PRIMERA
# 3         BIOLOGÍA GENERAL        1  08:00-09:30  Lu-Vie    PRIMERA
# 4  FOTOGRAFÍA PUBLICITARIA        1  08:00-09:30  Lu-Vie    PRIMERA
#
#         tipo  inscritos  examinados   modalidad
# 0  ORDINARIA         47          44  PRESENCIAL
# 1  ORDINARIA         36          31  PRESENCIAL
# 2  ORDINARIA        124         115    EN LINEA
# 3  ORDINARIA         60          52  PRESENCIAL
# 4  ORDINARIA         36          33  PRESENCIAL

# %%
# mostramos los ultimos valores del dataframe
df.tail()
# Out:
#            fecha   codigo                                      facultad  \
# 2974  2022-10-20   DEL1-D                           Facultad de Derecho
# 2975  2022-10-20   DEL1-D                           Facultad de Derecho
# 2976  2022-10-20   INT7-I                 Facultad de Ciencias Sociales
# 2977  2022-10-20  COI1-AC  Facultad de Informática y Ciencias Aplicadas
# 2978  2022-10-20  SIPRI-T  Facultad de Informática y Ciencias Aplicadas
#
#                                                   area  \
# 2974                                           DERECHO
# 2975                                           DERECHO
# 2976                                           IDIOMAS
# 2977              CIENCIAS APLICADAS AREA ARQUITECTURA
# 2978  CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
#
#                                                 materia  seccion      horario  \
# 2974                                  DERECHO LABORAL I        1  06:30-08:00
# 2975                                  DERECHO LABORAL I        1  06:30-08:00
# 2976                            INGLÉS PARA TURISMO VII        1  06:30-08:00
# 2977                     CONSTRUCCIÓN E INSTALACIONES I        1  06:30-08:00
# 2978  INGLÉS TÉCNICO IV (SISTEMAS INTEGRADOS ADMINIS...        1  06:30-08:00
#
#             dias evaluacion       tipo  inscritos  examinados modalidad
# 2974      Ma-Jue    TERCERA  ORDINARIA         63          57  EN LINEA
# 2975      Ma-Jue    TERCERA   DIFERIDA         63           6  EN LINEA
# 2976  Ma-Jue-Sab    TERCERA  ORDINARIA          6           5  EN LINEA
# 2977      Ma-Jue    TERCERA  ORDINARIA         44          39  EN LINEA
# 2978  Ma-Jue-Sab    TERCERA  ORDINARIA         15          15  EN LINEA

# %%
# mostramos los primeros 10 valores del dataframe
df.head(10)
# Out:
#         fecha   codigo                                      facultad  \
# 0  2022-08-22   DEIN-H                 Facultad de Ciencias Sociales
# 1  2022-08-22  EPRO-AC                 Facultad de Ciencias Sociales
# 2  2022-08-22   ING1-H                 Facultad de Ciencias Sociales
# 3  2022-08-22   BIOG-H                 Facultad de Ciencias Sociales
# 4  2022-08-22   FOPU-H                 Facultad de Ciencias Sociales
# 5  2022-08-22   EXOE-H                 Facultad de Ciencias Sociales
# 6  2022-08-22   MAT1-T  Facultad de Informática y Ciencias Aplicadas
# 7  2022-08-22   EDAV-C                 Facultad de Ciencias Sociales
# 8  2022-08-22   FILO-H                 Facultad de Ciencias Sociales
# 9  2022-08-22   FONO-I                 Facultad de Ciencias Sociales
#
#                                                area  \
# 0                                        PSICOLOGIA
# 1                                      ANTROPOLOGIA
# 2                                           IDIOMAS
# 3                                        PSICOLOGIA
# 4                                    COMUNICACIONES
# 5                                           IDIOMAS
# 6  CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
# 7                                    COMUNICACIONES
# 8                                      ANTROPOLOGIA
# 9                                           IDIOMAS
#
#                                 materia  seccion      horario    dias  \
# 0                 DESARROLLO INDIVIDUAL        3  08:00-09:30  Lu-Vie
# 1                                 ÉTICA        2  08:00-09:30  Lu-Vie
# 2                              INGLÉS I        4  08:00-09:30  Lu-Vie
# 3                      BIOLOGÍA GENERAL        1  08:00-09:30  Lu-Vie
# 4               FOTOGRAFÍA PUBLICITARIA        1  08:00-09:30  Lu-Vie
# 5  EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL        3  08:00-09:30  Lu-Vie
# 6                          MATEMÁTICA I        1  08:00-09:30  Lu-Vie
# 7              EDICIÓN DE AUDIO Y VIDEO        1  08:00-09:30  Lu-Vie
# 8                             FILOSOFÍA        3  08:00-09:30  Lu-Vie
# 9                             FONOLOGÍA        1  08:00-09:30  Lu-Vie
#
#   evaluacion       tipo  inscritos  examinados   modalidad
# 0    PRIMERA  ORDINARIA         47          44  PRESENCIAL
# 1    PRIMERA  ORDINARIA         36          31  PRESENCIAL
# 2    PRIMERA  ORDINARIA        124         115    EN LINEA
# 3    PRIMERA  ORDINARIA         60          52  PRESENCIAL
# 4    PRIMERA  ORDINARIA         36          33  PRESENCIAL
# 5    PRIMERA  ORDINARIA        130         127    EN LINEA
# 6    PRIMERA  ORDINARIA         46          45  PRESENCIAL
# 7    PRIMERA  ORDINARIA         10           9  PRESENCIAL
# 8    PRIMERA  ORDINARIA         21          20  PRESENCIAL
# 9    PRIMERA  ORDINARIA         68          67    EN LINEA

# %%
# cargamos los nombres de las columnas del dataframe
nombre_columnas = df.columns
# convertimos el resultado a una lista para poder manipularlo como lista si lo deseamos
print(list(nombre_columnas))
# Out:
# ['fecha', 'codigo', 'facultad', 'area', 'materia', 'seccion', 'horario', 'dias', 'evaluacion', 'tipo', 'inscritos', 'examinados', 'modalidad']

# %%
# cargamos todos los valores de la columna "materia" a nuestra variable y la convertimos en una lista
Nombres_asignaturas = df['materia'].values.tolist()
# mostramos los primeros 20 nombres de la columna Name que ahora esta en una lista
print(Nombres_asignaturas[:20])
# Out:
# ['DESARROLLO INDIVIDUAL', 'ÉTICA', 'INGLÉS I', 'BIOLOGÍA GENERAL', 'FOTOGRAFÍA PUBLICITARIA', 'EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL', 'MATEMÁTICA I', 'EDICIÓN DE AUDIO Y VIDEO', 'FILOSOFÍA', 'FONOLOGÍA', 'LENGUAJE UNIFICADO MODELADO (UML)', 'MÉTODOS DE INVESTIGACIÓN EDUCATIVA', 'ESTUDIO DE LA CONSTITUCIÓN', 'PRÁCTICA DOCENTE I', 'MATEMÁTICA II', 'PRODUCCIÓN EN TELEVISIÓN', 'TEORÍA DE LA COMUNICACIÓN', 'URBANISMO I', 'INFORMÁTICA', 'INGLÉS II']

# %% [markdown]
# # Manipulacion del dataframe

# %%
'''Vamos a manipular el dataframe, para eso empezamos con los nombres de las columnas'''
# Cambiamos los nombres de las columnas para que todo este en minusculas, para eso primero convertimos a string usando str
df.columns = df.columns.str.lower()
# mostramos el nombre de las columnas, ahora todas estan en minuscula
print(df.columns)
# Reemplazamos los espacios, en este caso los quitamos
df.columns = df.columns.str.replace(' ','')
print(df.columns)
# ahora se reemplaza el punto por guion bajo
df.columns = df.columns.str.replace('.','_')
print(df.columns)
# estos son ejemplos de manipulacion de un dataframe, dependiendo de la calidad de la data y su uso
# es posible que no se necesite hacer muchos cambios o al contrario y si se necesite cambiar los nombres
# Out:
# Index(['fecha', 'codigo', 'facultad', 'area', 'materia', 'seccion', 'horario',
#        'dias', 'evaluacion', 'tipo', 'inscritos', 'examinados', 'modalidad'],
#       dtype='object')
# Index(['fecha', 'codigo', 'facultad', 'area', 'materia', 'seccion', 'horario',
#        'dias', 'evaluacion', 'tipo', 'inscritos', 'examinados', 'modalidad'],
#       dtype='object')
# Index(['fecha', 'codigo', 'facultad', 'area', 'materia', 'seccion', 'horario',
#        'dias', 'evaluacion', 'tipo', 'inscritos', 'examinados', 'modalidad'],
#       dtype='object')
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# En la columna de nombres, se encuentran nombres con un formato incorrecto, por lo tanto se procede a reemplazar
# Se modifica el dataframe df, y se selecciona la columna 'materia'
df['materia'] = df['materia'].str.replace(".*(?=Matema)", "")
# podemos ver que ya no dice Matematicas  y ahora solo dice Matema ticas
df.head(20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          fecha   codigo                                      facultad  \
# 0   2022-08-22   DEIN-H                 Facultad de Ciencias Sociales
# 1   2022-08-22  EPRO-AC                 Facultad de Ciencias Sociales
# 2   2022-08-22   ING1-H                 Facultad de Ciencias Sociales
# 3   2022-08-22   BIOG-H                 Facultad de Ciencias Sociales
# 4   2022-08-22   FOPU-H                 Facultad de Ciencias Sociales
# 5   2022-08-22   EXOE-H                 Facultad de Ciencias Sociales
# 6   2022-08-22   MAT1-T  Facultad de Informática y Ciencias Aplicadas
# 7   2022-08-22   EDAV-C                 Facultad de Ciencias Sociales
# 8   2022-08-22   FILO-H                 Facultad de Ciencias Sociales
# 9   2022-08-22   FONO-I                 Facultad de Ciencias Sociales
# 10  2022-08-22   AYDS-I  Facultad de Informática y Ciencias Aplicadas
# 11  2022-08-22   METI-A                 Facultad de Ciencias Sociales
# 12  2022-08-22   CDLA-E                           Facultad de Derecho
# 13  2022-08-22   PRD1-H                 Facultad de Ciencias Sociales
# 14  2022-08-22   MAT2-E  Facultad de Informática y Ciencias Aplicadas
# 15  2022-08-22   PDTV-H                 Facultad de Ciencias Sociales
# 16  2022-08-22   TCOM-H                 Facultad de Ciencias Sociales
# 17  2022-08-22  URB1-AC  Facultad de Informática y Ciencias Aplicadas
# 18  2022-08-22   INF1-I  Facultad de Informática y Ciencias Aplicadas
# 19  2022-08-22   ING2-H                 Facultad de Ciencias Sociales
#
#                                                 area  \
# 0                                         PSICOLOGIA
# 1                                       ANTROPOLOGIA
# 2                                            IDIOMAS
# 3                                         PSICOLOGIA
# 4                                     COMUNICACIONES
# 5                                            IDIOMAS
# 6   CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
# 7                                     COMUNICACIONES
# 8                                       ANTROPOLOGIA
# 9                                            IDIOMAS
# 10                                       INFORMATICA
# 11                                           IDIOMAS
# 12                                           DERECHO
# 13                                           IDIOMAS
# 14  CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
# 15                                    COMUNICACIONES
# 16                                    COMUNICACIONES
# 17              CIENCIAS APLICADAS AREA ARQUITECTURA
# 18                                       INFORMATICA
# 19                                           IDIOMAS
#
#                                  materia  seccion      horario    dias  \
# 0                  DESARROLLO INDIVIDUAL        3  08:00-09:30  Lu-Vie
# 1                                  ÉTICA        2  08:00-09:30  Lu-Vie
# 2                               INGLÉS I        4  08:00-09:30  Lu-Vie
# 3                       BIOLOGÍA GENERAL        1  08:00-09:30  Lu-Vie
# 4                FOTOGRAFÍA PUBLICITARIA        1  08:00-09:30  Lu-Vie
# 5   EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL        3  08:00-09:30  Lu-Vie
# 6                           MATEMÁTICA I        1  08:00-09:30  Lu-Vie
# 7               EDICIÓN DE AUDIO Y VIDEO        1  08:00-09:30  Lu-Vie
# 8                              FILOSOFÍA        3  08:00-09:30  Lu-Vie
# 9                              FONOLOGÍA        1  08:00-09:30  Lu-Vie
# 10     LENGUAJE UNIFICADO MODELADO (UML)        2  08:00-09:30  Lu-Vie
# 11    MÉTODOS DE INVESTIGACIÓN EDUCATIVA        1  08:00-09:30  Lu-Vie
# 12            ESTUDIO DE LA CONSTITUCIÓN        3  08:00-09:30  Lu-Vie
# 13                    PRÁCTICA DOCENTE I        1  08:00-09:30  Lu-Vie
# 14                         MATEMÁTICA II        2  08:00-09:30  Lu-Vie
# 15              PRODUCCIÓN EN TELEVISIÓN        1  08:00-09:30  Lu-Vie
# 16             TEORÍA DE LA COMUNICACIÓN        1  08:00-09:30  Lu-Vie
# 17                           URBANISMO I        1  08:00-09:30  Lu-Vie
# 18                           INFORMÁTICA        4  08:00-09:30  Lu-Vie
# 19                             INGLÉS II        1  08:00-09:30  Lu-Vie
#
#    evaluacion       tipo  inscritos  examinados   modalidad
# 0     PRIMERA  ORDINARIA         47          44  PRESENCIAL
# 1     PRIMERA  ORDINARIA         36          31  PRESENCIAL
# 2     PRIMERA  ORDINARIA        124         115    EN LINEA
# 3     PRIMERA  ORDINARIA         60          52  PRESENCIAL
# 4     PRIMERA  ORDINARIA         36          33  PRESENCIAL
# 5     PRIMERA  ORDINARIA        130         127    EN LINEA
# 6     PRIMERA  ORDINARIA         46          45  PRESENCIAL
# 7     PRIMERA  ORDINARIA         10           9  PRESENCIAL
# 8     PRIMERA  ORDINARIA         21          20  PRESENCIAL
# 9     PRIMERA  ORDINARIA         68          67    EN LINEA
# 10    PRIMERA  ORDINARIA         21          21  PRESENCIAL
# 11    PRIMERA  ORDINARIA         51          48    EN LINEA
# 12    PRIMERA  ORDINARIA         22          21  PRESENCIAL
# 13    PRIMERA  ORDINARIA         18          17    EN LINEA
# 14    PRIMERA  ORDINARIA         11           9  PRESENCIAL
# 15    PRIMERA  ORDINARIA         74          74    EN LINEA
# 16    PRIMERA  ORDINARIA         19          18  PRESENCIAL
# 17    PRIMERA  ORDINARIA         34          33    EN LINEA
# 18    PRIMERA  ORDINARIA         81          73    EN LINEA
# 19    PRIMERA  ORDINARIA        131         126    EN LINEA

# %%
# Ya que los indices de las filas a veces se repiten, en este caso preferimos utilizar la columna 'name' como indice
df = df.set_index("materia")
df.head(20)
# Out:
#                                            fecha   codigo  \
# materia
# DESARROLLO INDIVIDUAL                 2022-08-22   DEIN-H
# ÉTICA                                 2022-08-22  EPRO-AC
# INGLÉS I                              2022-08-22   ING1-H
# BIOLOGÍA GENERAL                      2022-08-22   BIOG-H
# FOTOGRAFÍA PUBLICITARIA               2022-08-22   FOPU-H
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL  2022-08-22   EXOE-H
# MATEMÁTICA I                          2022-08-22   MAT1-T
# EDICIÓN DE AUDIO Y VIDEO              2022-08-22   EDAV-C
# FILOSOFÍA                             2022-08-22   FILO-H
# FONOLOGÍA                             2022-08-22   FONO-I
# LENGUAJE UNIFICADO MODELADO (UML)     2022-08-22   AYDS-I
# MÉTODOS DE INVESTIGACIÓN EDUCATIVA    2022-08-22   METI-A
# ESTUDIO DE LA CONSTITUCIÓN            2022-08-22   CDLA-E
# PRÁCTICA DOCENTE I                    2022-08-22   PRD1-H
# MATEMÁTICA II                         2022-08-22   MAT2-E
# PRODUCCIÓN EN TELEVISIÓN              2022-08-22   PDTV-H
# TEORÍA DE LA COMUNICACIÓN             2022-08-22   TCOM-H
# URBANISMO I                           2022-08-22  URB1-AC
# INFORMÁTICA                           2022-08-22   INF1-I
# INGLÉS II                             2022-08-22   ING2-H
#
#                                                                           facultad  \
# materia
# DESARROLLO INDIVIDUAL                                Facultad de Ciencias Sociales
# ÉTICA                                                Facultad de Ciencias Sociales
# INGLÉS I                                             Facultad de Ciencias Sociales
# BIOLOGÍA GENERAL                                     Facultad de Ciencias Sociales
# FOTOGRAFÍA PUBLICITARIA                              Facultad de Ciencias Sociales
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL                 Facultad de Ciencias Sociales
# MATEMÁTICA I                          Facultad de Informática y Ciencias Aplicadas
# EDICIÓN DE AUDIO Y VIDEO                             Facultad de Ciencias Sociales
# FILOSOFÍA                                            Facultad de Ciencias Sociales
# FONOLOGÍA                                            Facultad de Ciencias Sociales
# LENGUAJE UNIFICADO MODELADO (UML)     Facultad de Informática y Ciencias Aplicadas
# MÉTODOS DE INVESTIGACIÓN EDUCATIVA                   Facultad de Ciencias Sociales
# ESTUDIO DE LA CONSTITUCIÓN                                     Facultad de Derecho
# PRÁCTICA DOCENTE I                                   Facultad de Ciencias Sociales
# MATEMÁTICA II                         Facultad de Informática y Ciencias Aplicadas
# PRODUCCIÓN EN TELEVISIÓN                             Facultad de Ciencias Sociales
# TEORÍA DE LA COMUNICACIÓN                            Facultad de Ciencias Sociales
# URBANISMO I                           Facultad de Informática y Ciencias Aplicadas
# INFORMÁTICA                           Facultad de Informática y Ciencias Aplicadas
# INGLÉS II                                            Facultad de Ciencias Sociales
#
#                                                                                   area  \
# materia
# DESARROLLO INDIVIDUAL                                                       PSICOLOGIA
# ÉTICA                                                                     ANTROPOLOGIA
# INGLÉS I                                                                       IDIOMAS
# BIOLOGÍA GENERAL                                                            PSICOLOGIA
# FOTOGRAFÍA PUBLICITARIA                                                 COMUNICACIONES
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL                                           IDIOMAS
# MATEMÁTICA I                          CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
# EDICIÓN DE AUDIO Y VIDEO                                                COMUNICACIONES
# FILOSOFÍA                                                                 ANTROPOLOGIA
# FONOLOGÍA                                                                      IDIOMAS
# LENGUAJE UNIFICADO MODELADO (UML)                                          INFORMATICA
# MÉTODOS DE INVESTIGACIÓN EDUCATIVA                                             IDIOMAS
# ESTUDIO DE LA CONSTITUCIÓN                                                     DERECHO
# PRÁCTICA DOCENTE I                                                             IDIOMAS
# MATEMÁTICA II                         CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
# PRODUCCIÓN EN TELEVISIÓN                                                COMUNICACIONES
# TEORÍA DE LA COMUNICACIÓN                                               COMUNICACIONES
# URBANISMO I                                       CIENCIAS APLICADAS AREA ARQUITECTURA
# INFORMÁTICA                                                                INFORMATICA
# INGLÉS II                                                                      IDIOMAS
#
#                                       seccion      horario    dias evaluacion  \
# materia
# DESARROLLO INDIVIDUAL                       3  08:00-09:30  Lu-Vie    PRIMERA
# ÉTICA                                       2  08:00-09:30  Lu-Vie    PRIMERA
# INGLÉS I                                    4  08:00-09:30  Lu-Vie    PRIMERA
# BIOLOGÍA GENERAL                            1  08:00-09:30  Lu-Vie    PRIMERA
# FOTOGRAFÍA PUBLICITARIA                     1  08:00-09:30  Lu-Vie    PRIMERA
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL        3  08:00-09:30  Lu-Vie    PRIMERA
# MATEMÁTICA I                                1  08:00-09:30  Lu-Vie    PRIMERA
# EDICIÓN DE AUDIO Y VIDEO                    1  08:00-09:30  Lu-Vie    PRIMERA
# FILOSOFÍA                                   3  08:00-09:30  Lu-Vie    PRIMERA
# FONOLOGÍA                                   1  08:00-09:30  Lu-Vie    PRIMERA
# LENGUAJE UNIFICADO MODELADO (UML)           2  08:00-09:30  Lu-Vie    PRIMERA
# MÉTODOS DE INVESTIGACIÓN EDUCATIVA          1  08:00-09:30  Lu-Vie    PRIMERA
# ESTUDIO DE LA CONSTITUCIÓN                  3  08:00-09:30  Lu-Vie    PRIMERA
# PRÁCTICA DOCENTE I                          1  08:00-09:30  Lu-Vie    PRIMERA
# MATEMÁTICA II                               2  08:00-09:30  Lu-Vie    PRIMERA
# PRODUCCIÓN EN TELEVISIÓN                    1  08:00-09:30  Lu-Vie    PRIMERA
# TEORÍA DE LA COMUNICACIÓN                   1  08:00-09:30  Lu-Vie    PRIMERA
# URBANISMO I                                 1  08:00-09:30  Lu-Vie    PRIMERA
# INFORMÁTICA                                 4  08:00-09:30  Lu-Vie    PRIMERA
# INGLÉS II                                   1  08:00-09:30  Lu-Vie    PRIMERA
#
#                                            tipo  inscritos  examinados  \
# materia
# DESARROLLO INDIVIDUAL                 ORDINARIA         47          44
# ÉTICA                                 ORDINARIA         36          31
# INGLÉS I                              ORDINARIA        124         115
# BIOLOGÍA GENERAL                      ORDINARIA         60          52
# FOTOGRAFÍA PUBLICITARIA               ORDINARIA         36          33
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL  ORDINARIA        130         127
# MATEMÁTICA I                          ORDINARIA         46          45
# EDICIÓN DE AUDIO Y VIDEO              ORDINARIA         10           9
# FILOSOFÍA                             ORDINARIA         21          20
# FONOLOGÍA                             ORDINARIA         68          67
# LENGUAJE UNIFICADO MODELADO (UML)     ORDINARIA         21          21
# MÉTODOS DE INVESTIGACIÓN EDUCATIVA    ORDINARIA         51          48
# ESTUDIO DE LA CONSTITUCIÓN            ORDINARIA         22          21
# PRÁCTICA DOCENTE I                    ORDINARIA         18          17
# MATEMÁTICA II                         ORDINARIA         11           9
# PRODUCCIÓN EN TELEVISIÓN              ORDINARIA         74          74
# TEORÍA DE LA COMUNICACIÓN             ORDINARIA         19          18
# URBANISMO I                           ORDINARIA         34          33
# INFORMÁTICA                           ORDINARIA         81          73
# INGLÉS II                             ORDINARIA        131         126
#
#                                        modalidad
# materia
# DESARROLLO INDIVIDUAL                 PRESENCIAL
# ÉTICA                                 PRESENCIAL
# INGLÉS I                                EN LINEA
# BIOLOGÍA GENERAL                      PRESENCIAL
# FOTOGRAFÍA PUBLICITARIA               PRESENCIAL
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL    EN LINEA
# MATEMÁTICA I                          PRESENCIAL
# EDICIÓN DE AUDIO Y VIDEO              PRESENCIAL
# FILOSOFÍA                             PRESENCIAL
# FONOLOGÍA                               EN LINEA
# LENGUAJE UNIFICADO MODELADO (UML)     PRESENCIAL
# MÉTODOS DE INVESTIGACIÓN EDUCATIVA      EN LINEA
# ESTUDIO DE LA CONSTITUCIÓN            PRESENCIAL
# PRÁCTICA DOCENTE I                      EN LINEA
# MATEMÁTICA II                         PRESENCIAL
# PRODUCCIÓN EN TELEVISIÓN                EN LINEA
# TEORÍA DE LA COMUNICACIÓN             PRESENCIAL
# URBANISMO I                             EN LINEA
# INFORMÁTICA                             EN LINEA
# INGLÉS II                               EN LINEA

# %%
# al ver el dataframe vemos que hay valores NaN, estos son campos sin data o vacios, vamos a verificar en todo
# el dataframe los valores vacios que encontremos
df.isnull().any()
# Out:
# fecha         False
# codigo        False
# facultad      False
# area          False
# seccion       False
# horario       False
# dias          False
# evaluacion    False
# tipo          False
# inscritos     False
# examinados    False
# modalidad     False
# dtype: bool

# %% [markdown]
# Vemos que la unica columna que tiene datos vacios es type2

# %%
# Contamos la cantidad de datos NaN que existen en el dataframe, para eso utilizamos isna() y luego sum()
df.isna().sum()
# Out:
# fecha         0
# codigo        0
# facultad      0
# area          0
# seccion       0
# horario       0
# dias          0
# evaluacion    0
# tipo          0
# inscritos     0
# examinados    0
# modalidad     0
# dtype: int64

# %% [markdown]
# Vemos que en la columna type2 hay 386 datos vacios, podemos rellenar esos datos o simplemente obviar la columna.

# %%
# En este caso vamos a eliminar la columna de examinados ya que posee una gran cantidad de valores vacios 
# y no los consideramos importantes
# Utilizamos drop() se le pasa inplace=True para que no retorne una copia, ya que queremos que lo borre de 
# nuestro dataframe, axis es para eliminar por fila y 1 por columna, en este caso por eso especificamos el nombre de la columna
df.drop('facultad', inplace=True, axis=1)

# %%
df.head(10)
# Out:
#                                            fecha   codigo  \
# materia
# DESARROLLO INDIVIDUAL                 2022-08-22   DEIN-H
# ÉTICA                                 2022-08-22  EPRO-AC
# INGLÉS I                              2022-08-22   ING1-H
# BIOLOGÍA GENERAL                      2022-08-22   BIOG-H
# FOTOGRAFÍA PUBLICITARIA               2022-08-22   FOPU-H
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL  2022-08-22   EXOE-H
# MATEMÁTICA I                          2022-08-22   MAT1-T
# EDICIÓN DE AUDIO Y VIDEO              2022-08-22   EDAV-C
# FILOSOFÍA                             2022-08-22   FILO-H
# FONOLOGÍA                             2022-08-22   FONO-I
#
#                                                                                   area  \
# materia
# DESARROLLO INDIVIDUAL                                                       PSICOLOGIA
# ÉTICA                                                                     ANTROPOLOGIA
# INGLÉS I                                                                       IDIOMAS
# BIOLOGÍA GENERAL                                                            PSICOLOGIA
# FOTOGRAFÍA PUBLICITARIA                                                 COMUNICACIONES
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL                                           IDIOMAS
# MATEMÁTICA I                          CIENCIAS APLICADAS AREA INDUSTRIAL Y MATEMATICAS
# EDICIÓN DE AUDIO Y VIDEO                                                COMUNICACIONES
# FILOSOFÍA                                                                 ANTROPOLOGIA
# FONOLOGÍA                                                                      IDIOMAS
#
#                                       seccion      horario    dias evaluacion  \
# materia
# DESARROLLO INDIVIDUAL                       3  08:00-09:30  Lu-Vie    PRIMERA
# ÉTICA                                       2  08:00-09:30  Lu-Vie    PRIMERA
# INGLÉS I                                    4  08:00-09:30  Lu-Vie    PRIMERA
# BIOLOGÍA GENERAL                            1  08:00-09:30  Lu-Vie    PRIMERA
# FOTOGRAFÍA PUBLICITARIA                     1  08:00-09:30  Lu-Vie    PRIMERA
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL        3  08:00-09:30  Lu-Vie    PRIMERA
# MATEMÁTICA I                                1  08:00-09:30  Lu-Vie    PRIMERA
# EDICIÓN DE AUDIO Y VIDEO                    1  08:00-09:30  Lu-Vie    PRIMERA
# FILOSOFÍA                                   3  08:00-09:30  Lu-Vie    PRIMERA
# FONOLOGÍA                                   1  08:00-09:30  Lu-Vie    PRIMERA
#
#                                            tipo  inscritos   modalidad
# materia
# DESARROLLO INDIVIDUAL                 ORDINARIA         47  PRESENCIAL
# ÉTICA                                 ORDINARIA         36  PRESENCIAL
# INGLÉS I                              ORDINARIA        124    EN LINEA
# BIOLOGÍA GENERAL                      ORDINARIA         60  PRESENCIAL
# FOTOGRAFÍA PUBLICITARIA               ORDINARIA         36  PRESENCIAL
# EXPRESIÓN ORAL Y ESCRITA DEL ESPAÑOL  ORDINARIA        130    EN LINEA
# MATEMÁTICA I                          ORDINARIA         46  PRESENCIAL
# EDICIÓN DE AUDIO Y VIDEO              ORDINARIA         10  PRESENCIAL
# FILOSOFÍA                             ORDINARIA         21  PRESENCIAL
# FONOLOGÍA                             ORDINARIA         68    EN LINEA

# %%
# ahora haces una cuenta de los valores que existen en la columna materia
# value_counts() nos retorna cuantos valores hay de cada tipo
df["seccion"].value_counts()
# Out:
# 1     1650
# 2      615
# 3      263
# 4      122
# 5       81
# 6       45
# 7       35
# 8       28
# 10      28
# 9       25
# 11      24
# 13      19
# 12      18
# 14      13
# 15       5
# 16       3
# 17       3
# 18       2
# Name: seccion, dtype: int64

# %%
# podemos ver mas informacion sobre nuestro dataset si utilizamos describe()
# los datos que se muestran dependen del dataset en nuestro dataframe
df.describe()
# Out:
#            seccion    inscritos
# count  2979.000000  2979.000000
# mean      2.324606    55.625378
# std       2.523969    33.637022
# min       1.000000     1.000000
# 25%       1.000000    27.000000
# 50%       1.000000    51.000000
# 75%       2.000000    78.000000
# max      18.000000   138.000000

# %% [markdown]
# Podemos ver valores minimos, maximos, la media, cantidad de datos, etc.

# %% [markdown]
# # Matplotlib.pyplot

# %%
# importamos matplotlib y de esta utilizamos pyplot como plt
import matplotlib.pyplot as plt
# podemos empezar a generar una grafica solo pasandole unos valores al comando plot 
plt.plot([1,2,3,4])
# cuando solo se pasa una lista o array, plot asume que son valores en el eje Y y el asigna los
# valores del eje X.
# le damos un nombre al eje Y 
plt.ylabel('eje Y')
# mostramos la grafica
plt.show()

# %%
# ahora le pasamos dos listas a plot, donde la primera es el eje X y la segunda es el eje Y
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
# podemos definir un estilo y color para nuestra grafica, se utilizan los mismos que MATLAB
# podemos ver que el tercer valor 'ro' significa puntos rojos
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# definimos los rangos de los ejes, 0 a 6 el eje X y 0 a 20 el eje Y
plt.axis([0, 6, 0, 20])

plt.show()

# %%
# podemos tener varios graficos en la misma ventana y a cada uno asignarle distintos estilos
# creamos un array de 0 a 5 en intervalos de 0.2
t = np.arange(0., 5., 0.2)
# graficamos con lineas rojas t vs t, t vs t cuadrado en azul y t vs t cubo en verde
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# podemos hacer graficos de barra utilizando plt.bar
# creamos una figura que es donde se mostrara el grafico y le indicamos el tamaño
plt.figure(figsize=(15,10))
# creamos nuestro grafico, utilizando como eje X todos los valores unicos del dataframe en la columna type1
# y en el eje Y le pasamos la cantidad de entradas que hay de cada tipo
plt.bar(df['type1'].unique(), df['type1'].value_counts())
# asignamos un nombre al eje x
plt.xlabel('Tipos')
# nombre del eje y
plt.ylabel('Total')
# titulo de la grafica
plt.title('Distribucion de tipos')
# mostramos la grafica
plt.show()

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
import math
var1="procesamiento de datos"
var2="utilizando python"
print(var1 + " "+var2)
# Out:
# procesamiento de datos utilizando python

# %%
print(type(var1))
len(var2)
# Out:
# <class 'str'>
# 17

# %%
var1=51
var2=69
print(var1+var2)
# Out:
# 120

# %%
var3=3.141598765
type(var3)
# Out:
# float

# %%
var3=3.141598756
print(var3)
# Out:
# 3.141598756

# %%
var3=var3*var2+var1/5
print(var3)
# Out:
# 18486.351677316

# %%
var1=True
type(var1)
# Out:
# bool

# %%
import math
var1=5.6 * math.pi
print(var1)
# Out:
# 17.59291886010284

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA as skl

# %%
#metodos para manejo de cadenas y texto
var1="Introducción a python"
var2="utilizando cadenas y texto"
var3="123"

# %%
#metodos descriptivos de cadenas y texto
var1.find("a")
var1.count("0")
var2.islower()
var2.isupper()
var3.isnumeric()
# Out:
# 13

# %%
len(var1)
# Out:
# 21

# %%
var2.count("a")
# Out:
# 3

# %%
#metodos de transformación de cadenas y texto
var1.upper()
# Out:
# 'INTRODUCCIÓN A PYTHON'

# %%
var1.lower()
# Out:
# 'introducción a python'

# %%
var2.title()
# Out:
# 'Utilizando Cadenas Y Texto'

# %%
var2.replace("a","A")
# Out:
# 'utilizAndo cAdenAs y texto'

# %%
var3.split("-")
# Out:
# ['123']

# %%
#operadores aritmeticos
x=10
x//3
x%3
x**2
# Out:
# 3

# %%
y="procesamiento de datos"
x+=5  # x=x+5
x-=5  # x=x-5
x/=5  # x=x/5
y+= " utilizando python 3"
print(y)
# Out:
# procesamiento de datos utilizando python 3

# %%
#operadores logicos
x=5
y=9
x==y
x!=y
x>y
x>=y
x<=y

x>y and x<5
True and False
not(x>y)
x<y or x<5
# Out:
# True

# %%
#operadores de identidad
x is x
x is y
z=y
z is y
# Out:
# True

# %%
#operador de pertenencia
lista1=[1,2,3,4,5]
3 in lista1
10 in lista1
# Out:
# False

# %%
(x>9) & (x<7) #and
# Out:
# False

# %%
(x>9) | (x<7) #or
# Out:
# True

# %%
#estructuras de datos - colecciones, listas, diccionarios, arreglos

listaX=[1,2,3,4,5,"Procesamiento de datos",[5.2,3.6,4.5]]
listaX[0]
listaX[5]
listaX[6]
listaX[1:3]
listaX[3:]
listaX[-1]
listaX[6][2]
listaX[-1][-1]
listaX[0]=10
listaX
listaX.append([True, False, True])
listaX
listaY=listaX[6]
listaY=sorted(listaY, reverse=False)
listaY
listaX
del(listaX[5])
listaX
# Out:
# [10, 2, 3, 4, 5, [5.2, 3.6, 4.5], [True, False, True]]

# %%
#Diccionario
carro={"marca":"nissan", "año":"2006", "motor":"1.6L"}
carro
# Out:
# {'marca': 'nissan', 'año': '2006', 'motor': '1.6L'}

# %%
x=carro.get("motor")
x=carro.keys()
x=carro.values()
x
# Out:
# dict_values(['nissan', '2006', '1.6L'])
